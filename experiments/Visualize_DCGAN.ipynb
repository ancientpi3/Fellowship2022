# %% [markdown]
# <a href="https://colab.research.google.com/github/ancientpi3/Fellowship2022/blob/main/experiments/Visualize_DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import cv2
import numpy as np
from google.colab import drive
from google.colab import files
from zipfile import ZipFile
import cv2
import os
from PIL import Image
from keras.initializers import RandomNormal
from google.colab.patches import cv2_imshow
import gc

# %%
drive.mount('/content/gdrive')
filename = "/content/gdrive/MyDrive/celeba_train.zip"


with ZipFile(filename, "r",) as zip:
  zip.extractall(path="/content/celeba_train")
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ancientpi3/Fellowship2022.git
from Fellowship2022.modules import DCGAN
# Out:
# Cloning into 'Fellowship2022'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 221 (delta 36), reused 0 (delta 0), pack-reused 140
# Receiving objects: 100% (221/221), 2.62 MiB | 9.81 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
folder_path_train="/content/celeba_train"
x_train = DCGAN.folder_to_numpy(folder_path_train,take=40)

# %%
plt.figure()
count=5
f, axarr = plt.subplots(1,count)

for i in range(count):
  axarr[i].imshow((x_train[i]+1)/2)
  axarr[i].axis('off')

# %%
g_model = DCGAN.generator()
g_model.load_weights("/content/celeba_generator_40000_v1.h5")

# %%
fake_images = DCGAN.grab_fake_batch(g_model, 25)

# %%
plt.figure()
count=5
offset=9

f, axarr = plt.subplots(1,count)

for i in range(count):
  axarr[i].imshow((fake_images[i+offset]+1)/2)
  axarr[i].axis('off')

# %%
g_model = DCGAN.generator()
g_model.load_weights("/content/celeba_generator_20000_v1.h5")
fake_images = DCGAN.grab_fake_batch(g_model, 25)
plt.figure()
count=5
offset=0
f, axarr = plt.subplots(1,count)
for i in range(count):
  axarr[i].imshow((fake_images[i+offset]+1)/2)
  axarr[i].axis('off')

# %%
g_model = DCGAN.generator()
g_model.load_weights("/content/celeba_generator_4000_v1.h5")
fake_images = DCGAN.grab_fake_batch(g_model, 25)
plt.figure()
count=5
offset=0
f, axarr = plt.subplots(1,count)
for i in range(count):
  axarr[i].imshow((fake_images[i+offset]+1)/2)
  axarr[i].axis('off')

# %%
g_model = DCGAN.generator()
g_model.load_weights("/content/celeba_generator_400_v1.h5")
fake_images = DCGAN.grab_fake_batch(g_model, 25)
plt.figure()
count=5
offset=10
f, axarr = plt.subplots(1,count)
for i in range(count):
  axarr[i].imshow((fake_images[i+offset]+1)/2)
  axarr[i].axis('off')

# %%
g_model = DCGAN.generator()
g_model.load_weights("/content/celeba_generator_40_v1.h5")
fake_images = DCGAN.grab_fake_batch(g_model, 25)
plt.figure()
count=5
offset=5
f, axarr = plt.subplots(1,count)
for i in range(count):
  axarr[i].imshow((fake_images[i+offset]+1)/2)
  axarr[i].axis('off')
